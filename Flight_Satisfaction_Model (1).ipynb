# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style()

# %%
# read in the data
data = pd.read_csv("C:/Users/StarKid/Desktop/Class/Fall_2023/data_201/project/Invistico_Airline.csv")

# %%
data.head()
# Out:
#   satisfaction   Customer Type  Age   Type of Travel     Class  \
# 0    satisfied  Loyal Customer   65  Personal Travel       Eco
# 1    satisfied  Loyal Customer   47  Personal Travel  Business
# 2    satisfied  Loyal Customer   15  Personal Travel       Eco
# 3    satisfied  Loyal Customer   60  Personal Travel       Eco
# 4    satisfied  Loyal Customer   70  Personal Travel       Eco
#
#    Flight Distance  Seat comfort  Departure/Arrival time convenient  \
# 0              265             0                                  0
# 1             2464             0                                  0
# 2             2138             0                                  0
# 3              623             0                                  0
# 4              354             0                                  0
#
#    Food and drink  Gate location  ...  Online support  Ease of Online booking  \
# 0               0              2  ...               2                       3
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 22 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   satisfaction                       129880 non-null  object
#  1   Customer Type                      129880 non-null  object
#  2   Age                                129880 non-null  int64
#  3   Type of Travel                     129880 non-null  object
#  4   Class                              129880 non-null  object
#  5   Flight Distance                    129880 non-null  int64
#  6   Seat comfort                       129880 non-null  int64
#  7   Departure/Arrival time convenient  129880 non-null  int64
#  8   Food and drink                     129880 non-null  int64
#  9   Gate location                      129880 non-null  int64
#  10  Inflight wifi service              129880 non-null  int64
# ...

# %%
# check missing values
data.isna().sum()
# Out:
# satisfaction                           0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Seat comfort                           0
# Departure/Arrival time convenient      0
# Food and drink                         0
# Gate location                          0
# Inflight wifi service                  0
# Inflight entertainment                 0
# Online support                         0
# Ease of Online booking                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Cleanliness                            0
# Online boarding                        0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             393
# dtype: int64

# %%
# check for duplicates
data.duplicated().sum()
# Out:
# 0

# %%
data.describe()
# Out:
#                  Age  Flight Distance   Seat comfort  \
# count  129880.000000    129880.000000  129880.000000
# mean       39.427957      1981.409055       2.838597
# std        15.119360      1027.115606       1.392983
# min         7.000000        50.000000       0.000000
# 25%        27.000000      1359.000000       2.000000
# 50%        40.000000      1925.000000       3.000000
# 75%        51.000000      2544.000000       4.000000
# max        85.000000      6951.000000       5.000000
#
#        Departure/Arrival time convenient  Food and drink  Gate location  \
# count                      129880.000000   129880.000000  129880.000000
# mean                            2.990645        2.851994       2.990422
# std                             1.527224        1.443729       1.305970
# min                             0.000000        0.000000       0.000000
# 25%                             2.000000        2.000000       2.000000
# ...

# %%
data.describe(include="O")
# Out:
#        satisfaction   Customer Type   Type of Travel     Class
# count        129880          129880           129880    129880
# unique            2               2                2         3
# top       satisfied  Loyal Customer  Business travel  Business
# freq          71087          106100            89693     62160

# %%
# let's look into our target variable
data["satisfaction"].unique()
# Out:
# array(['satisfied', 'dissatisfied'], dtype=object)

# %%
data.columns
# Out:
# Index(['satisfaction', 'Customer Type', 'Age', 'Type of Travel', 'Class',
#        'Flight Distance', 'Seat comfort', 'Departure/Arrival time convenient',
#        'Food and drink', 'Gate location', 'Inflight wifi service',
#        'Inflight entertainment', 'Online support', 'Ease of Online booking',
#        'On-board service', 'Leg room service', 'Baggage handling',
#        'Checkin service', 'Cleanliness', 'Online boarding',
#        'Departure Delay in Minutes', 'Arrival Delay in Minutes'],
#       dtype='object')

# %%
# Lets begin our eda exploration
import seaborn as sns 
import matplotlib.pyplot as plt

sns.catplot(data=df, x='Customer Type', kind='count')
plt.title('Counts of Customer Type')
plt.show()

# %%
df['Type of Travel'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
# Lets get a feel for the distrubution of age
# young people are not as likley to travel so no need to be loyal

sns.histplot(data=df, x='Age', hue='Customer Type')
plt.show()

# %%
sns.catplot(data=df, x='Type of Travel', kind='count')
plt.title('Types of Travel')
plt.show()

# %%
df['Leg room service'].unique()
# Out:
# array([0, 4, 3, 2, 5, 1], dtype=int64)

# %%
df['Cleanliness'].unique()
sns.catplot(data=df,x='Cleanliness', kind='count')
plt.show()

# %%
df['Class'].unique()

order = df['Class'].value_counts()
sns.catplot(data=df, x='Class', kind='count', order=order.index)
plt.title('Customer Class')
plt.show()

# %%
# lets compare the class depending on type of travel 

sns.catplot(data=df, x='Type of Travel', hue='Class', kind='count')
plt.title('Type of Travel By Class')
plt.show()

# %% [markdown]
# # Bi-variate analysis

# %%
# select numeric columns
numeric_cols = [col for col in data.columns if data[col].dtype != "O"]
cat_cols = [col for col in data.columns if data[col].dtype == "O"]

# %%
numeric_cols
# Out:
# ['Age',
#  'Flight Distance',
#  'Seat comfort',
#  'Departure/Arrival time convenient',
#  'Food and drink',
#  'Gate location',
#  'Inflight wifi service',
#  'Inflight entertainment',
#  'Online support',
#  'Ease of Online booking',
#  'On-board service',
#  'Leg room service',
#  'Baggage handling',
#  'Checkin service',
#  'Cleanliness',
#  'Online boarding',
#  'Departure Delay in Minutes',
#  'Arrival Delay in Minutes']

# %%
cat_cols
# Out:
# ['satisfaction', 'Customer Type', 'Type of Travel', 'Class']

# %%
# # plot distribution of numeric variables/columns
# sns.pairplot(data[numeric_cols])
# plt.show()

# %%
def object_type_distribution_plot(df):
    """ This gives the distribution of the variables with the object data type
    """
    for var in cat_cols:

        print(df[var].describe(include='object'))
        plt.figure(figsize=(10,5))
        ax = sns.countplot(data=df, x=var)
        #rotate label if too long
        plt.xticks(rotation=90)
        plt.show()



def numeric_type_distribution_plot(df):
    """ This gives the distribution of the variables with the numeric data type
    """
    for var in numeric_cols:
        print(df[var].describe())
        plt.figure(figsize=(10,5))
        ax = sns.distplot(df[var])
        #rotate label if too long
        plt.xticks(rotation=90)
        plt.show()

# %%
object_type_distribution_plot(data)
# Out:
# count        129880
# unique            2
# top       satisfied
# freq          71087
# Name: satisfaction, dtype: object
# count             129880
# unique                 2
# top       Loyal Customer
# freq              106100
# Name: Customer Type, dtype: object
# count              129880
# unique                  2
# top       Business travel
# freq                89693
# Name: Type of Travel, dtype: object
# count       129880
# unique           3
# top       Business
# freq         62160
# Name: Class, dtype: object

# %%
numeric_type_distribution_plot(data)
# Out:
# count    129880.000000
# mean         39.427957
# std          15.119360
# min           7.000000
# 25%          27.000000
# 50%          40.000000
# 75%          51.000000
# max          85.000000
# Name: Age, dtype: float64
# C:\Users\StarKid\AppData\Local\Temp\ipykernel_57348\2011443115.py:21: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(df[var])
# count    129880.000000
# mean       1981.409055
# std        1027.115606
# min          50.000000
# 25%        1359.000000
# 50%        1925.000000
# 75%        2544.000000
# max        6951.000000
# Name: Flight Distance, dtype: float64
# ...

# %% [markdown]
# # Bi-variate Analysis

# %%
sns.boxplot(x="Class", y="Age", data=data)
#rotate label if too long
plt.xticks(rotation=90);
plt.show()

# %%
# check for correlation among numerical variables
corr_df = data[numeric_cols].corr()
corr_df
# Out:
#                                         Age  Flight Distance  Seat comfort  \
# Age                                1.000000        -0.249625      0.008784
# Flight Distance                   -0.249625         1.000000     -0.042409
# Seat comfort                       0.008784        -0.042409      1.000000
# Departure/Arrival time convenient  0.039055         0.001350      0.434951
# Food and drink                     0.015749        -0.004649      0.715997
# Gate location                     -0.000547        -0.002409      0.405300
# Inflight wifi service              0.013965         0.012230      0.129131
# Inflight entertainment             0.130511        -0.027542      0.426447
# Online support                     0.121201        -0.032022      0.120278
# Ease of Online booking             0.071594        -0.022299      0.211531
# On-board service                   0.066704        -0.032559      0.121149
# ...

# %%
corr_df[corr_df>=0.9] # using 0.9 as threshold for multicollinearity
# Out:
#                                    Age  Flight Distance  Seat comfort  \
# Age                                1.0              NaN           NaN
# Flight Distance                    NaN              1.0           NaN
# Seat comfort                       NaN              NaN           1.0
# Departure/Arrival time convenient  NaN              NaN           NaN
# Food and drink                     NaN              NaN           NaN
# Gate location                      NaN              NaN           NaN
# Inflight wifi service              NaN              NaN           NaN
# Inflight entertainment             NaN              NaN           NaN
# Online support                     NaN              NaN           NaN
# Ease of Online booking             NaN              NaN           NaN
# On-board service                   NaN              NaN           NaN
# Leg room service                   NaN              NaN           NaN
# ...

# %% [markdown]
# * `Departure Delay in Minutes` is highly correlated with  `Arrival Delay in Minutes` (0.97), Hence, this implies multicollinearity, and we can only use one of the two variables as predictors

# %% [markdown]
# #  Data Preprocessing

# %%
# make data copy
df = data.copy()

# %%
for col in cat_cols:
    print(col)
    print(df[col].unique())
# Out:
# satisfaction
# ['satisfied' 'dissatisfied']
# Customer Type
# ['Loyal Customer' 'disloyal Customer']
# Type of Travel
# ['Personal Travel' 'Business travel']
# Class
# ['Eco' 'Business' 'Eco Plus']

# %%
# Manual Label Encoding for categorical variables
satisfaction_mapper = {'satisfied':0, 'dissatisfied':1}
cust_type_mapper = {'Loyal Customer':0, 'disloyal Customer':1}
travel_type_mapper = {'Personal Travel':0, 'Business travel':1}
class_mapper  = {'Eco':0, 'Business':2, 'Eco Plus':1}

df["satisfaction"] = df["satisfaction"].map(satisfaction_mapper)
df["Customer Type"] = df["Customer Type"].map(cust_type_mapper)
df["Type of Travel"] = df["Type of Travel"].map(travel_type_mapper)
df["Class"] = df["Class"].map(class_mapper)

# %%
# drop unprocessed and invalid colums (We will be dropping Arrival delay since it is correlated with Departure delay and also contained missing values)
df.drop(columns=["Arrival Delay in Minutes"], inplace=True)

# %% [markdown]
# # Separate Independent variables and Dependent variable

# %%
# assign independent features to X
X = df.drop(columns=["Class"])
y = df["Class"]

# %%
X.head()
# Out:
#    satisfaction  Customer Type  Age  Type of Travel  Flight Distance  \
# 0             0              0   65               0              265
# 1             0              0   47               0             2464
# 2             0              0   15               0             2138
# 3             0              0   60               0              623
# 4             0              0   70               0              354
#
#    Seat comfort  Departure/Arrival time convenient  Food and drink  \
# 0             0                                  0               0
# 1             0                                  0               0
# 2             0                                  0               0
# 3             0                                  0               0
# 4             0                                  0               0
#
#    Gate location  Inflight wifi service  Inflight entertainment  \
# 0              2                      2                       4
# ...

# %%
y
# Out:
# 0         0
# 1         2
# 2         0
# 3         0
# 4         0
#          ..
# 129875    0
# 129876    2
# 129877    0
# 129878    0
# 129879    0
# Name: Class, Length: 129880, dtype: int64

# %%
# do train test split
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# %%
# data scaling (applying normalization)
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(X_train)
X_trained_scaled = X_train.copy()
X_trained_scaled[X_trained_scaled.columns] = scaler.transform(X_trained_scaled)
X_test_scaled = X_test.copy()
X_test_scaled[X_test_scaled.columns] = scaler.transform(X_test_scaled)

# %% [markdown]
# # Modeling

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()
clf.fit(X_trained_scaled,y_train) # train the model
# Out:
# C:\Users\StarKid\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
test_pred = clf.predict(X_test_scaled)

# %%
# evaluate performance using accuracy, f1-score 
from sklearn.metrics import accuracy_score, classification_report

acc_score = accuracy_score(test_pred, y_test)
class_rep = classification_report(test_pred, y_test)

print("Accuracy: ", acc_score)
print("Report:\n ", class_rep)
# Out:
# Accuracy:  0.7734318858433425
# Report:
#                 precision    recall  f1-score   support
#
#            0       0.80      0.76      0.78     18375
#            1       0.00      0.00      0.00         0
#            2       0.87      0.78      0.82     20589
#
#     accuracy                           0.77     38964
#    macro avg       0.56      0.52      0.53     38964
# weighted avg       0.83      0.77      0.80     38964
# C:\Users\StarKid\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
class_pred = clf.predict(X_test_scaled) # class prediction
prob_pred = clf.predict_proba(X_test_scaled) # class probability

# %%
from sklearn.multiclass import OneVsOneClassifier


# One Versus All (OvA)
model_ova = LogisticRegression(multi_class='ovr')
model_ova.fit(X_trained_scaled, y_train)
y_pred_ova = model_ova.predict(X_test_scaled)
y_pred_proba_ova = model_ova.predict_proba(X_test_scaled)

# One Versus One (OvO)
model_ovo = OneVsOneClassifier(LogisticRegression())
model_ovo.fit(X_trained_scaled, y_train)
y_pred_ovo = model_ovo.predict(X_test_scaled)

# %%
# Displaying the predictions
print("OvA Predictions:", y_pred_ova[:5])
print("OvA Probabilities:\n", y_pred_proba_ova[:5])
print("OvO Predictions:", y_pred_ovo[:5])
# Out:
# OvA Predictions: [2 2 2 0 0]
# OvA Probabilities:
#  [[0.37402587 0.0935875  0.53238663]
#  [0.10475988 0.04413107 0.85110905]
#  [0.06303248 0.02874746 0.90822006]
#  [0.73198708 0.0588427  0.20917022]
#  [0.80056046 0.07507382 0.12436572]]
# OvO Predictions: [2 2 2 0 0]

# %% [markdown]
# To interpret the result of the logistic regression results, we can as well look into the parameter estimates:

# %%
clf.intercept_
# Out:
# array([ 2.9697023 ,  1.24084252, -4.21054482])

# %%
clf.coef_
# Out:
# array([[ 0.2016321 ,  1.01049564, -0.32606024, -1.75640618, -0.87553731,
#          0.94078102, -0.09494911, -0.34851094,  0.01371407, -0.10006348,
#         -0.53372617, -0.3473063 ,  0.52251763, -0.32705508, -0.11399702,
#         -0.30222967, -0.29571561, -0.43665892, -0.03087035,  0.72895659],
#        [ 0.20731121, -0.64461985, -0.45095143, -0.88182362, -1.01972353,
#          0.9293143 , -0.14204432, -0.23060471, -0.07287634, -0.07980777,
#         -0.6814297 , -0.47134058,  0.59117702, -0.58071243, -0.11566666,
#         -0.35005481, -0.30144549, -0.24102961,  0.04106636,  0.12311835],
#        [-0.40894332, -0.36587579,  0.77701166,  2.6382298 ,  1.89526084,
#         -1.87009532,  0.23699343,  0.57911566,  0.05916227,  0.17987125,
#          1.21515588,  0.81864688, -1.11369465,  0.90776751,  0.22966368,
#          0.65228448,  0.5971611 ,  0.67768853, -0.01019601, -0.85207493]])
